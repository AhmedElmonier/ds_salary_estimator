# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data.csv')

# %%
pd.set_option('display.max_columns', None)  
df.head()
# Out:
#                                            Job Title  \
# 0  Data Scientist - Finance & Business Operations...
# 1                                     Data Scientist
# 2            Machine Learning Engineer, Data Science
# 3                         Data Engineer 5 - Contract
# 4                           Data Analyst - eCommerce
#
#                 Salary Estimate  \
# 0    $55K-$97K (Glassdoor est.)
# 1   $64K-$106K (Glassdoor est.)
# 2  $122K-$209K (Glassdoor est.)
# 3    $73K-$88K (Glassdoor est.)
# 4      $65K-$79K(Employer est.)
#
#                                      Job Description  Rating  \
# 0  EMPLOYMENT VALUE PROPOSITION: Mental Health Ce...     4.0
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.1
# 2  Atlassian is continuing to hire for all open r...     4.3
# 3  Purposes\n\nThis is a contract position that w...     4.2
# 4  Data Analyst - eCommerce\nCorporate Headquarte...     3.3
#
# ...

# %%
df.describe()
# Out:
#             Rating      Founded       Hourly  Company Provided  min_salary  \
# count  2266.000000  2266.000000  2266.000000       2266.000000  2266.00000
# mean      3.662092  1869.857458     0.003972          0.002207    89.89850
# std       1.052472   444.115555     0.062910          0.046932    23.17299
# min      -1.000000    -1.000000     0.000000          0.000000    15.00000
# 25%       3.400000  1960.000000     0.000000          0.000000    79.00000
# 50%       3.800000  1994.000000     0.000000          0.000000    91.00000
# 75%       4.200000  2010.000000     0.000000          0.000000   103.00000
# max       5.000000  2019.000000     1.000000          1.000000   212.00000
#
#         max_salary   avg_salary   same_state  company_age       python  \
# count  2266.000000  2266.000000  2266.000000  2266.000000  2266.000000
# mean    131.199912   110.463813     0.563107    44.848632     0.726390
# std      31.204562    26.351337     0.496111    70.650347     0.445909
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2266 entries, 0 to 2265
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2266 non-null   object
#  1   Salary Estimate    2266 non-null   object
#  2   Job Description    2266 non-null   object
#  3   Rating             2266 non-null   float64
#  4   Company Name       2266 non-null   object
#  5   Location           2266 non-null   object
#  6   Headquarters       2266 non-null   object
#  7   Size               2266 non-null   object
#  8   Founded            2266 non-null   int64
#  9   Type of ownership  2266 non-null   object
#  10  Industry           2266 non-null   object
#  11  Sector             2266 non-null   object
#  12  Revenue            2266 non-null   object
#  13  Competitors        2266 non-null   object
#  14  Hourly             2266 non-null   int64
#  15  Company Provided   2266 non-null   int64
# ...

# %%
df.shape
# Out:
# (2266, 32)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'Company Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'state', 'same_state', 'company_age', 'python',
#        'r_studio', 'spark', 'aws', 'excel', 'job_simp', 'seniority',
#        'desc_len', 'num_comp'],
#       dtype='object')

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.company_age.hist()

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'Company Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'state', 'same_state', 'company_age', 'python',
#        'r_studio', 'spark', 'aws', 'excel', 'job_simp', 'seniority',
#        'desc_len', 'num_comp'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
plt.bar(df.avg_salary, df.job_simp)
plt.xlabel('Avg. Salary')
plt.ylabel('Jobs')
plt.show()

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'Company Provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'state', 'same_state', 'company_age', 'python',
#        'r_studio', 'spark', 'aws', 'excel', 'job_simp', 'seniority',
#        'desc_len', 'num_comp'],
#       dtype='object')

# %%
corr = df[['company_age', 'avg_salary', 'python', 'Founded', 'num_comp']].corr()

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
           square=True, linewidth=.5, cbar_kws={'shrink': .5})

# %%
df_cat = df[['Size', 'Industry', 'Sector', 'Revenue', 'company_txt', 'state', 
 'python', 'r_studio', 'spark', 'aws', 'excel', 'job_simp', 'seniority' ]]

# %%
for i in df_cat.columns:
    counts = df_cat[i].value_counts()[:30]
    print('Graph for %s total = %d' % (i, len(counts)))
    plt.figure(figsize=(16,4))
    chart = sns.barplot(x=counts.index, y=counts)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Size total = 8
# Graph for Industry total = 30
# Graph for Sector total = 23
# Graph for Revenue total = 13
# Graph for company_txt total = 30
# Graph for state total = 30
# Graph for python total = 2
# Graph for r_studio total = 2
# Graph for spark total = 2
# Graph for aws total = 2
# Graph for excel total = 2
# Graph for job_simp total = 7
# Graph for seniority total = 2

# %%
pd.pivot_table(df, index='job_simp', values='avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          76.027397
# data engineer   108.875000
# data scientist  112.480437
# director        124.428571
# manager         106.384615
# mle             121.966667
# na               93.050505

# %%
pd.pivot_table(df, index=['job_simp', 'seniority'], values='avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        na          68.712963
#                senior      96.815789
# data engineer  na         100.209091
#                senior     131.571429
# data scientist na         109.805080
#                senior     143.340764
# director       na         130.600000
#                senior     109.000000
# manager        na         106.954545
#                senior     103.250000
# mle            na         111.095238
#                senior     147.333333
# na             na          79.848485
#                senior     119.454545

# %%
pd.pivot_table(df, index='state', values='avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#         avg_salary
# state
# ['CA']  131.885401
# ['WA']  124.922222
# ['MA']  117.140097
# ['RI']  113.875000
# ['NJ']  113.000000
# ['MD']  110.133333
# ['NM']  109.666667
# ['NY']  108.617925
# ['VA']  105.115000
# ['NH']  105.000000
# ['IL']  104.228571
# ['CO']  103.933333
# ['OR']  103.472222
# ['GA']  100.888889
# ['TX']   98.189655
# ['UT']   97.831169
# ['MN']   97.200000
# ['KS']   96.000000
# ['OH']   94.136364
# ['MO']   93.761905
# ['TN']   90.850000
# ['HI']   89.969697
# ['DC']   89.920732
# ['IA']   89.500000
# ['NC']   87.272727
# ['IN']   86.416667
# ['PA']   86.075000
# ['MI']   84.812500
# ['CT']   84.642857
# ['KY']   82.500000
# ['AL']   81.625000
# ['AZ']   78.514925
# ['NE']   77.265152
# ['OK']   75.500000
# ['FL']   74.450000
# ['DE']   72.500000
# ['WV']   63.500000
# ['WI']   62.285714
# ['MS']   57.000000
# ['ME']   55.500000
# ['SC']   55.000000
# ['ID']   49.000000

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 
                'Hourly', 'python', 'r_studio', 'spark', 'aws', 'excel', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    147.687500
#  2.3    133.544776
#  4.7    123.500000
#  4.1    121.136364
#  3.5    119.579268
#  2.8    119.412500
#  3.7    118.717033
#  3.4    118.151376
#  1.5    116.500000
#  4.5    113.964286
#  5.0    113.553333
#  4.2    113.115894
#  2.6    112.125000
#  3.8    111.140351
#  4.3    109.903226
#  3.9    109.653646
#  4.6    104.958333
#  4.8    103.852941
#  3.6    103.489583
#  3.2    102.238372
#  4.0    102.093939
#  2.5     99.333333
#  3.3     97.820513
#  4.9     96.085714
#  3.1     95.433333
#  3.0     94.156250
#  2.7     91.750000
#  4.4     91.315789
#  2.2     76.750000
#  2.9     68.987179
#  2.4     62.000000
# Industry
#                                            avg_salary
# Industry
# Financial Analytics & Research             147.500000
# Other Retail Stores                        140.125000
# Venture Capital & Private Equity           127.500000
# Internet                                   126.162568
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python', values = 'avg_salary', aggfunc = 'count')
# Out:
# python                                0      1
# Revenue
# $1 to $2 billion (USD)             80.0   34.0
# $1 to $5 million (USD)              8.0   14.0
# $10 to $25 million (USD)           14.0  155.0
# $10+ billion (USD)                 96.0  250.0
# $100 to $500 million (USD)        109.0  203.0
# $2 to $5 billion (USD)             12.0   90.0
# $25 to $50 million (USD)           76.0   80.0
# $5 to $10 billion (USD)             1.0   80.0
# $5 to $10 million (USD)            69.0   13.0
# $50 to $100 million (USD)          14.0  157.0
# $500 million to $1 billion (USD)    9.0   92.0
# Less than $1 million (USD)          NaN    6.0
# Unknown / Non-Applicable          132.0  472.0

# %%
import os
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

wc.to_file('Words.jpg')
